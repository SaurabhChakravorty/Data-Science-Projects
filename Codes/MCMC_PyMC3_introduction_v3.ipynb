# %%
#MCMC introduction
#Based on PyMC3 docu exmaples 
#Powered by Jan Nagler

import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
# set output floats to 5 significant digits throughout the journey
# %precision 4 
# %matplotlib inline
# Base your life on the meaning of life
np.random.seed(42)

# %% [raw]
# Here, Markov Chain Monte Carlo (MCMC) is used to infer the distributions of model parameters. Instead of starting with distributions for the parameters of a model and using them to calculate a surrogate distribution as the output of the algorithm, we start with a realzation of that output and look for paramter input distributions. The type of the parameter input distributions, along with initial parameters are specified.

# %%
# Model: Simple random additive noise

# Groundtruth parameter values
alpha, sigma = 1, 1 # intercept and std
beta = [1, 2.5] # weights

# Size of surrogate dataset
size = 125

# Predictor variable
X1 = np.random.randn(size)
X2 = np.random.randn(size) * 0.3

# Surrogate data set
Y = alpha + beta[0]*X1 + beta[1]*X2 + np.random.randn(size)*sigma

# %%
#plot data, projections
fig, axes = plt.subplots(1, 2, sharex=True, figsize=(10,4))
axes[0].scatter(X1, Y)
axes[1].scatter(X2, Y)
axes[0].set_ylabel('Y'); axes[0].set_xlabel('X1'); axes[1].set_xlabel('X2');

# %%
# This is a massive lib for MCMC 
import pymc3 as pm
print('Running on PyMC3 v{}'.format(pm.__version__))
# pip install git+https://github.com/pymc-devs/pymc3
# just run this commend in your shell
# Out:
# Running on PyMC3 v3.8

# %% [markdown]
# Define prior distributions for the parameters for which we will be trying to infer posterior distributions

# %%
# Build a model 
basic_model = pm.Model()

with basic_model: #context manager

    # Priors for unknown model parameters
    alpha = pm.Normal('alpha', mu=0, sigma=10)
    beta = pm.Normal('beta', mu=0, sigma=10, shape=2)
    sigma = pm.HalfNormal('sigma', sigma=1)

    # Expected value of outcome
    # Determinitic random variable, means sharply defined by delta function over data and model param
    mu = alpha + beta[0]*X1 + beta[1]*X2 

    # Likelihood (sampling distribution) of observations, given out surrogate data Y
    # Called observed stochastic variable 
    Y_obs = pm.Normal('Y_obs', mu=mu, sigma=sigma, observed=Y)

# %% [markdown]
# Perform MCMC: Sample from our prior distribution, simulate the model, and evaluate the likelihood of the data given those input parameters, based on our "basic model", and the "noise" distribution, our (surrogate) data Y. Use Bayesian inference to decide whether to keep the trial points or throw them away. Choose a new set of points and start over.

# %%
# MCMC Sampling method 
with basic_model:
    
    # Compute MAP estimate
    start = pm.find_MAP() # args, e.g., model=basic_model, Powell method (no derivatives needed)
    print("Start", start)
    
    # instantiate sampler steps: Optional 
    #step = pm.Slice()
    #step = pm.Metropolis()
    step = pm.NUTS()
    
    # draw 5000 posterior samples
    trace = pm.sample(500, step=step)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='17' class='' max='17' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [17/17 00:00<00:00 logp = -175.67, ||grad|| = 15.841]
#     </div>
# Start {'alpha': array(1.0704), 'beta': array([1.1027, 2.7388]), 'sigma_log__': array(-0.1088), 'sigma': array(0.8969)}
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6000' class='' max='6000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6000/6000 00:01<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 500 draw iterations (4_000 + 2_000 draws total) took 2 seconds.

# %%
pm.traceplot(trace)
#pm.autocorrplot(trace)
pm.pairplot(trace)
pm.energyplot(trace) # https://arxiv.org/pdf/1604.00695v1.pdf
pm.summary(trace).round(2)
# Out:
#          mean    sd  hpd_3%  hpd_97%  mcse_mean  mcse_sd  ess_mean  ess_sd  \
# alpha    1.07  0.08    0.92     1.24        0.0      0.0    3516.0  3511.0
# beta[0]  1.10  0.09    0.94     1.26        0.0      0.0    2907.0  2907.0
# beta[1]  2.74  0.28    2.23     3.26        0.0      0.0    2641.0  2572.0
# sigma    0.92  0.06    0.81     1.04        0.0      0.0    3248.0  3248.0
#
#          ess_bulk  ess_tail  r_hat
# alpha      3514.0    1656.0    1.0
# beta[0]    2928.0    1558.0    1.0
# beta[1]    2640.0    1588.0    1.0
# sigma      3135.0    1343.0    1.0

# %%
# And now to something completely different

# %%
# Sampling using steps that defined the MCMC method 
# Minimal Coin toss example with PyMC3
# compact form

basic_model = pm.Model()

with basic_model:
    
    size = 125
    alpha = 5
    beta = 2
    h = 75 # number of heads observed
    
    # define priors
    p = pm.Beta('p', alpha=alpha, beta=beta)

    # define likelihood
    y = pm.Binomial('y', n=size, p=p, observed=h)
    
    # Compute MAP estimate
    start = pm.find_MAP()
    
    # instantiate sampler steps: Optional 
    step = pm.Metropolis() # Discrete variables
    
    # draw 5000 posterior samples
    trace = pm.sample(1000, step=step)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 00:00<00:00 logp = -5.5662, ||grad|| = 13.857]
#     </div>
# Multiprocess sampling (4 chains in 4 jobs)
# Metropolis: [p]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:00<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1 seconds.
# The number of effective samples is smaller than 25% for some parameters.

# %%
pm.traceplot(trace);
pm.summary(trace).round(2)
# Out:
#    mean    sd  hpd_3%  hpd_97%  mcse_mean  mcse_sd  ess_mean  ess_sd  \
# p   0.6  0.04    0.53     0.68        0.0      0.0     877.0   872.0
#
#    ess_bulk  ess_tail  r_hat
# p     880.0     752.0    1.0

# %%
import scipy.stats as stats
plt.hist(trace['p'], 15, label='post', histtype='step')
x = np.linspace(0, 1, 100)
plt.plot(x, 100*stats.beta.pdf(x, alpha, beta), label='prior')
plt.legend(loc='best')
